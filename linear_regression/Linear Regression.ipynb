# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression


data = pd.read_csv('cost_revenue_clean.csv')

data.describe()
# Out:
# /Users/christopherespiritu/opt/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
x = pd.DataFrame(data, columns= ['production_budget_usd'])
y = pd.DataFrame(data, columns= ['worldwide_gross_usd'])

# %%
plt.figure(figsize=(10, 6))

# alpha - set point transparency
plt.scatter(x, y, alpha=0.3) 

# set plot title and x & y labels
plt.title("Film Cost v Global Revenue")
plt.xlabel('Production Budget in Dollars')
plt.ylabel('Worldwide Gross in Dollars')

plt.ylim(0, max(y.values) * 1.1)
plt.xlim(0, max(x.values) * 1.1)

# plt.show()

print()

# %% [markdown]
# ## Comuting the Line
#
#
# Residual Sum of Squares

# %%
from sklearn.linear_model import LinearRegression

regression = LinearRegression()
regression.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Slope Coefficient:

# %%
regression.coef_ # theta_1
# Out:
# array([[3.11150918]])

# %%
# Intercept
regression.intercept_
# Out:
# array([-7236192.72913975])

# %%
plt.figure(figsize=(10, 6))

plt.scatter(x, y, alpha=0.3) # transparency
plt.plot(x, regression.predict(x), color='red', linewidth='4')
plt.title("Film Cost v Global Revenue")
plt.xlabel('Production Budget in Dollars')
plt.ylabel('Worldwide Gross in Dollars')

plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)

plt.show()

# %% [markdown]
# The goodness of fit
# R^2

# %%
# amount of variation in film revenue that is explained by the film budget
regression.score(x, y)
# Out:
# 0.5496485356985729
